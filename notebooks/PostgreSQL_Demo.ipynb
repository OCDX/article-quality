# %%
# %load_ext sql

# %%
# %sql postgres://twg4_user:3axavey7=hakEyek@tw4-small.cnc4ebuyotg1.us-west-1.rds.amazonaws.com/twg4_db
# Out:
# 'Connected: twg4_user@twg4_db'

# %%
# %sql select * from pg_tables
# Out:
# 81 rows affected.
# [('tw4_db', 'job_archive_2014', 'twg4_user', None, False, False, False, False),
#  ('tw4_db', 'history', 'twg4_user', None, True, False, False, False),
#  ('tw4_db', 'tweetphiladelphia', 'twg4_user', None, False, False, False, False),
#  ('pg_catalog', 'pg_statistic', 'rdsadmin', None, True, False, False, False),
#  ('pg_catalog', 'pg_type', 'rdsadmin', None, True, False, False, False),
#  ('tw4_db', 'mention', 'twg4_user', None, True, False, False, False),
#  ('pg_catalog', 'pg_authid', 'rdsadmin', 'pg_global', True, False, False, False),
#  ('tw4_db', 'oauth', 'twg4_user', None, True, False, False, False),
#  ('tw4_db', 'roles', 'twg4_user', None, False, False, False, False),
#  ('tw4_db', 'job', 'twg4_user', None, True, False, False, False),
#  ('tw4_db', 'jobupdate_save', 'twg4_user', None, False, False, False, False),
#  ('pg_catalog', 'pg_user_mapping', 'rdsadmin', None, True, False, False, False),
# ...

# %%
# %sql select relname from pg_class where relkind='r' and relname !~ '^(pg_|sql_)'
# Out:
# 20 rows affected.
# [('job_archive_2014',),
#  ('history',),
#  ('tweetphiladelphia',),
#  ('mention',),
#  ('oauth',),
#  ('roles',),
#  ('job',),
#  ('jobupdate_save',),
#  ('MISSOURI',),
#  ('tweetcompton',),
#  ('tweetmemphis',),
#  ('tweet',),
#  ('tweetalabama',),
#  ('update_status',),
#  ('url',),
#  ('tweetchicago',),
#  ('UKRAINE',),
#  ('tweetneworleans',),
#  ('tweetnepal',),
#  ('hashtag',)]

# %%
# %sql SET search_path TO tw4_db
# Out:
# Done.
# []

# %%
# %sql SELECT * FROM roles
# Out:
# 0 rows affected.
# []

# %%
# %sql SELECT text,from_user_name FROM tweet WHERE from_user = '589716682'
# Out:
# 1 rows affected.
# [('I have lost so many lip gloss/ chap sticks over the years ', 'jessica_belle_')]
